# %%
from plots import *
from db_connector import RemoteDB
# Out:
# 2024-01-06 13:30:17,873 - matplotlib - DEBUG - matplotlib data path: /home/slnopriv/Documents/Education/UniBas/HS23/databases/project/repo/group-1/venv/lib64/python3.11/site-packages/matplotlib/mpl-data
# 2024-01-06 13:30:17,878 - matplotlib - DEBUG - CONFIGDIR=/home/slnopriv/.config/matplotlib
# 2024-01-06 13:30:17,880 - matplotlib - DEBUG - interactive is False
# 2024-01-06 13:30:17,880 - matplotlib - DEBUG - platform is linux
# 2024-01-06 13:30:17,910 - matplotlib - DEBUG - CACHEDIR=/home/slnopriv/.cache/matplotlib
# 2024-01-06 13:30:17,912 - matplotlib.font_manager - DEBUG - Using fontManager instance from /home/slnopriv/.cache/matplotlib/fontlist-v330.json

# %%
remote_db = RemoteDB()

# %%
plt_acc_by_weekday(remote_db)
# Out:
# 2024-01-06 13:30:20,415 - matplotlib.pyplot - DEBUG - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2024-01-06 13:30:20,416 - matplotlib.pyplot - DEBUG - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2024-01-06 13:30:20,418 - matplotlib.font_manager - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# 2024-01-06 13:30:20,419 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/slnopriv/Documents/Education/UniBas/HS23/databases/project/repo/group-1/venv/lib64/python3.11/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# ...

# %%
remote_db.close()
